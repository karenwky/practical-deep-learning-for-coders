# %% [markdown]
# <a href="https://www.kaggle.com/code/yyzz1010/02-lesson?scriptVersionId=238169530" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#Import libraries
from fastai.vision.all import *

# %%
# Download and decompress dataset
path = untar_data(URLs.PETS)/"images"
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='811712512' class='' max='811706944' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [811712512/811706944 00:15&lt;00:00]
#     </div>

# %%
path
# Out:
# Path('/root/.fastai/data/oxford-iiit-pet/images')

# %%
# Define function to classify cat
def is_cat(x): 
    return x[0].isupper()  # Filename starts with capital letter

# %%
# Create DataLoaders
dls = ImageDataLoaders.from_name_func(
    ".", 
    get_image_files(path), 
    valid_pct=0.2, 
    seed=42, 
    label_func=is_cat, 
    item_tfms=Resize(192)
)

# %%
# Create learner
learn = vision_learner(dls, resnet18, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 147MB/s]

# %%
# %%time
# Train model
learn.fine_tune(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.169552</td>
#       <td>0.066050</td>
#       <td>0.020298</td>
#       <td>00:19</td>
# ...

# %%
# Export model
learn.export("model.pkl")

# %% [markdown]
# Exported model is in `/kaggle/working/` directory under "Output" sidebar.
